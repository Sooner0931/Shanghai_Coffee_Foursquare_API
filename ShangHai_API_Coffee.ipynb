# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge beautifulsoup4 --yes
# !conda install -c conda-forge requests --yes
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library



print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
#   - defaults/linux-64::pywavelets==1.0.0=py37hdd07704_0
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be UPDATED:
#
#   beautifulsoup4      anaconda::beautifulsoup4-4.7.1-py36_1 --> conda-forge::beautifulsoup4-4.7.1-py36_1001
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata: done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
#   - defaults/linux-64::pywavelets==1.0.0=py37hdd07704_0
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be UPDATED:
#
#   requests                 anaconda::requests-2.21.0-py36_0 --> conda-forge::requests-2.22.0-py36_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# # A practice using Foursquare API's location data to check coffee shops in Shanghai geographical center.

# %% [markdown]
# ## Define the centroid needed for searching

# %%
address = '168 Zhoujin Rd, Huangpu, Shanghai, China'                 # A Costa Coffee (咖世家) located in [168 Zhoujin Rd | 昼锦路168号]

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of our centroid are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of our centroid are 31.226294, 121.4869945.

# %% [markdown]
# ## Define geographical info needed

# %%
# create map of Shanghai using latitude and longitude values
map_Shanghai = folium.Map(location=[latitude, longitude], zoom_start=10)

# %%
map_Shanghai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Define our search criteria

# %%
search_query = 'Coffee'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %% [markdown]
# ## Define 4square client info

# %%
CLIENT_ID = "*************************************************"                              # Sry, ommitted                        
CLIENT_SECRET = "**********************************************"                            # Sry, ommitted again
VERSION = "20190520"
LIMIT = 500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: *************************************************
# CLIENT_SECRET:**********************************************

# %% [markdown]
# ## Define URL and get JSON file

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},\
{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()

# %% [markdown]
# ## assign relevant part of JSON to venues

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
dataframe.count()
# Out:
# categories                   43
# hasPerk                      43
# id                           43
# location.address             25
# location.cc                  43
# location.city                39
# location.country             43
# location.crossStreet         13
# location.distance            43
# location.formattedAddress    43
# location.labeledLatLngs      43
# location.lat                 43
# location.lng                 43
# location.neighborhood         3
# location.postalCode           5
# location.state               39
# name                         43
# referralId                   43
# dtype: int64

# %% [markdown]
# ## Keep only columns that include venue name, location associated fields

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                 name       categories  \
# 0             Kafelaku Coffee (猫屎咖啡)             Café
# 1                 Costa Coffee (咖世家)      Coffee Shop
# 2          J.co Donuts & Coffee (杰酷)       Donut Shop
# 3                 Costa Coffee (咖世家)      Coffee Shop
# 4              Gucchio Coffee (古墙咖啡)      Coffee Shop
# 5             Pacific Coffee (太平洋咖啡)      Coffee Shop
# 6             Pacific Coffee (太平洋咖啡)      Coffee Shop
# 7             Pacific Coffee (太平洋咖啡)      Coffee Shop
# 8                 Costa Coffee (咖世家)      Coffee Shop
# 9               憨豆咖啡 Mr. Bean Coffee      Coffee Shop
# 10               Mr Bean Coffee Shop             Café
# 11                    Bin Dao Coffee             Café
# 12                     Coffee Midori      Coffee Shop
# 13                  Java Coffee Shop             Café
# 14                     Manner Coffee      Coffee Shop
# 15                      Coffee House      Coffee Shop
# 16                       More Coffee      Coffee Shop
# 17  The Coffee Bean & Tea Leaf (香啡缤)             Café
# 18                Luckin Coffee 瑞幸咖啡      Coffee Shop
# 19                     Seesaw Coffee      Coffee Shop
# 20                 UBC Coffee (上岛咖啡)      Coffee Shop
# 21                    Maancat Coffee      Coffee Shop
# 22                     Manner Coffee      Coffee Shop
# 23                        Zoo Coffee             None
# 24                Sundeck Coffee Bar             Café
# 25                       Yris Coffee      Coffee Shop
# 26                  Dimattina Coffee      Coffee Shop
# 36          NaN        NaN   NaN  51fcab23498ef01cc3e0db3d
# 37          NaN        NaN   上海市  5a658bbd0c9f310fa0c37a5a
# 38          NaN        NaN   上海市  4dba7e931e7251d53c7d4e22
# 39          NaN     200010   上海市  4bf2301b189f0f47791eb862
# 40  Lǎo běi mén        NaN   上海市  4d6b6ea635c9a0939fec43c7
# 41          NaN        NaN   上海市  5b409143446ea6002cc14f02
# 42          NaN        NaN   上海市  50c572b4e4b01b1b6eef4042

# %%
dataframe_filtered.name
# Out:
# 0               Kafelaku Coffee (猫屎咖啡)
# 1                   Costa Coffee (咖世家)
# 2            J.co Donuts & Coffee (杰酷)
# 3                   Costa Coffee (咖世家)
# 4                Gucchio Coffee (古墙咖啡)
# 5               Pacific Coffee (太平洋咖啡)
# 6               Pacific Coffee (太平洋咖啡)
# 7               Pacific Coffee (太平洋咖啡)
# 8                   Costa Coffee (咖世家)
# 9                 憨豆咖啡 Mr. Bean Coffee
# 10                 Mr Bean Coffee Shop
# 11                      Bin Dao Coffee
# 12                       Coffee Midori
# 13                    Java Coffee Shop
# 14                       Manner Coffee
# 15                        Coffee House
# 16                         More Coffee
# 17    The Coffee Bean & Tea Leaf (香啡缤)
# 18                  Luckin Coffee 瑞幸咖啡
# 19                       Seesaw Coffee
# 20                   UBC Coffee (上岛咖啡)
# 21                      Maancat Coffee
# 22                       Manner Coffee
# 23                          Zoo Coffee
# 24                  Sundeck Coffee Bar
# 25                         Yris Coffee
# 26                    Dimattina Coffee
# 27                Twosome+ Coffee 途尚咖啡
# 28                Luckin Coffee (瑞幸咖啡)
# 29                 Partner Coffee Meow
# 30                     Sun Deck Coffee
# 31                         ILLY Coffee
# 32                  Manabe Coffee 真锅咖啡
# 33                   茶缸 La Taza Coffee
# 34                        Essen Coffee
# 35               Seesaw Coffee(K11 B1)
# 36                       Penggo Coffee
# 37                      Habitat Coffee
# 38                   UBC Coffee (上岛咖啡)
# 39                     Starbucks (星巴克)
# 40                     Starbucks (星巴克)
# 41                    Hey Coffee (嘿咖啡)
# 42                     Starbucks (星巴克)
# Name: name, dtype: object

# %%
dataframe_filtered.count()
# Out:
# name                43
# categories          42
# address             25
# cc                  43
# city                39
# country             43
# crossStreet         13
# distance            43
# formattedAddress    43
# labeledLatLngs      43
# lat                 43
# lng                 43
# neighborhood         3
# postalCode           5
# state               39
# id                  43
# dtype: int64

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the geographical center of SH
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Geographical Center of SH',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=10,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.3
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Check ratings of several coffee shops

# %%
venue_id = '5219c6b1498ee106267e3eae' # Kafelaku Coffee (猫屎咖啡)
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/5219c6b1498ee106267e3eae?client_id=JRMAOQ23QH2AR2G01QNCFARI5IKTISMVT2PHM3D0DXKGHF5N&client_secret=M1P2CGJKPR0J1N1GMUV0P5CH1BGLFD3SHIPP4YTOFQ4NTATE&v=20190520'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto'])
# {'id': '5219c6b1498ee106267e3eae',
#  'name': 'Kafelaku Coffee (猫屎咖啡)',
#  'contact': {},
#  'location': {'lat': 31.22713085887843,
#   'lng': 121.48808037173434,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 31.22713085887843,
#     'lng': 121.48808037173434}],
#   'cc': 'CN',
#   'city': '上海市',
#   'state': '上海市',
#   'country': '中国',
#   'formattedAddress': ['上海市', '上海市', '中国']},
#  'canonicalUrl': 'https://foursquare.com/v/kafelaku-coffee-%E7%8C%AB%E5%B1%8E%E5%92%96%E5%95%A1/5219c6b1498ee106267e3eae',
#  'categories': [{'id': '4bf58dd8d48988d16d941735',
#    'name': 'Café',
#    'pluralName': 'Cafés',
#    'shortName': 'Café',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 1},
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '¥'},
#  'likes': {'count': 1,
#   'groups': [{'type': 'others',
#     'count': 1,
#     'items': [{'id': '874932',
#       'firstName': 'Alex',
#       'lastName': 'Llamas',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/874932_0wAXppfg_h-SvWy1pWFboo1ntMRmNVwsCtaNQS5XXT4Uzk2ueaa-ldi3docRZE9G8czuSt5yw.jpg'}}]}],
#   'summary': '1 Like'},
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 3,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 3,
#     'items': [{'id': '5251298411d27f33e8836362',
#       'createdAt': 1381050756,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/510118_slUN-95pDRfkmLsjVZKQmrbr2lw_was6gX50MASZcpo.jpg',
#       'width': 640,
#       'height': 640,
#       'user': {'id': '510118',
#        'firstName': 'JayChan',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/BXGM4D53OFBMXEOC.jpg'}},
#       'visibility': 'public'},
#      {'id': '523d89b4498e14f050038dfa',
#       'createdAt': 1379764660,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/8724979_EuI6o1F_5J1MdguLup9JTiKL6S1cD33o51mhaZ9yynE.jpg',
#       'width': 717,
#       'height': 959,
#       'user': {'id': '8724979',
#        'firstName': 'H',
#        'lastName': 'Bomb',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/40JELITIUVTNRYP4.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1377420977,
#  'tips': {'count': 1,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 1,
#     'items': [{'id': '523d89b211d24f0d2495c8a4',
#       'createdAt': 1379764658,
#       'text': "China's answer to Starbucks. They even use the same size names, tall, venti etc. ask for a Vietnamese coffee, hot (not on the menu) but if you make friends with the barista he'll sort it out for you.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/523d89b211d24f0d2495c8a4',
#       'photo': {'id': '523d89b4498e14f050038dfa',
#        'createdAt': 1379764660,
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/8724979_EuI6o1F_5J1MdguLup9JTiKL6S1cD33o51mhaZ9yynE.jpg',
#        'width': 717,
#        'height': 959,
#        'visibility': 'public'},
#       'photourl': 'https://fastly.4sqi.net/img/general/original/8724979_EuI6o1F_5J1MdguLup9JTiKL6S1cD33o51mhaZ9yynE.jpg',
#       'lang': 'en',
#       'likes': {'count': 0, 'groups': []},
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '8724979',
#        'firstName': 'H',
#        'lastName': 'Bomb',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/40JELITIUVTNRYP4.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/17dEHNr',
#  'timeZone': 'Asia/Shanghai',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '¥',
#     'count': 1,
#     'items': [{'displayName': 'Price',
#       'displayValue': '¥',
#       'priceTier': 1}]}]},
#  'bestPhoto': {'id': '5251298411d27f33e8836362',
#   'createdAt': 1381050756,
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/510118_slUN-95pDRfkmLsjVZKQmrbr2lw_was6gX50MASZcpo.jpg',
#   'width': 640,
#   'height': 640,
#   'visibility': 'public'}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4bf2301b189f0f47791eb862' # ID of Starbucks (星巴克)
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4bf2301b189f0f47791eb862?client_id=JRMAOQ23QH2AR2G01QNCFARI5IKTISMVT2PHM3D0DXKGHF5N&client_secret=M1P2CGJKPR0J1N1GMUV0P5CH1BGLFD3SHIPP4YTOFQ4NTATE&v=20190520'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '4bf2301b189f0f47791eb862',
#  'name': 'Starbucks (星巴克)',
#  'contact': {'phone': '+862163552271',
#   'formattedPhone': '+86 21 6355 2271',
#   'twitter': 'starbucks',
#   'instagram': 'starbucks',
#   'facebook': '22092443056',
#   'facebookUsername': 'Starbucks',
#   'facebookName': 'Starbucks'},
#  'location': {'address': '豫园路100号 | 100 Yuyuan Rd.',
#   'crossStreet': '豫园 | Yu Garden',
#   'lat': 31.228536577839012,
#   'lng': 121.48721181905799,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 31.228536577839012,
#     'lng': 121.48721181905799}],
#   'postalCode': '200010',
#   'cc': 'CN',
#   'city': '上海市',
#   'state': '上海市',
#   'country': '中国',
#   'formattedAddress': ['豫园路100号 | 100 Yuyuan Rd. (豫园 | Yu Garden)',
#    '上海市',
#    '上海市, 200010',
#    '中国']},
#  'canonicalUrl': 'https://foursquare.com/v/starbucks-%E6%98%9F%E5%B7%B4%E5%85%8B/4bf2301b189f0f47791eb862',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 14},
#  'url': 'http://www.starbucks.com.cn/en',
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '¥'},
#  'likes': {'count': 40,
#   'groups': [{'type': 'others', 'count': 40, 'items': []}],
#   'summary': '40 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 5.6,
#  'ratingColor': 'FF9600',
#  'ratingSignals': 75,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'http://www.starbucks.com.cn/en/menu/beverages',
#   'mobileUrl': 'http://www.starbucks.com.cn/en/menu/beverages',
#   'externalUrl': 'http://www.starbucks.com.cn/en/menu/beverages'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 232,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 232,
#     'items': [{'id': '5ce22c7aa5a315002cc26b80',
#       'createdAt': 1558326394,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/24952115_jNA3meQ1RGIAOK94iZLe_iB-3Mo-_0mpbF3i_uMJ4-s.jpg',
#       'width': 1920,
#       'height': 1440,
#       'user': {'id': '24952115',
#        'firstName': 'Sui',
#        'lastName': 'Fong',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/24952115-GGZWV51G4RCJZHXY.jpg'}},
#       'visibility': 'public'},
#      {'id': '5ca833d1aa6c95002c5d2e24',
#       'createdAt': 1554527185,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/58215838_K-SoLzLApv0X6S8EOXCiZVjfgTCCHnkRkcmBLluXQog.jpg',
#       'width': 1920,
#       'height': 1440,
#       'user': {'id': '58215838',
#        'firstName': 'Shirley',
#        'lastName': 'Chen',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/58215838_Urogdz9a_SSb3Bjy5KY090l9h9SIi7kNKj8cXrq8YxwtaoXQEhcFQWaVWEZIPqFx-wWwEctNk.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1274163227,
#  'tips': {'count': 14,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 14,
#     'items': [{'id': '508f86e6e4b0a3242733328e',
#       'createdAt': 1351583462,
#       'text': 'I was here!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/508f86e6e4b0a3242733328e',
#       'lang': 'en',
#       'likes': {'count': 3,
#        'groups': [{'type': 'others',
#          'count': 3,
#          'items': [{'id': '149405',
#            'firstName': 'Brunold',
#            'lastName': 'Loidl',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/149405_1AAQXWG4_66Lv2HV3zlmOWVI98nAWl4nIi1T3uPFawxt5ujtte3ZXUy-ZwZIlFKFZ1cZTWK5N.jpg'}},
#           {'id': '25305939',
#            'firstName': 'dhines',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/25305939-HUPHSBULZXSJH0MZ.jpg'}},
#           {'id': '2639169',
#            'firstName': 'Chester',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/REVZQ3JBNJX15L0J.jpg'}}]}],
#        'summary': '3 likes'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '1448858',
#        'firstName': 'John Luke',
#        'lastName': 'Chica',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1448858-VG3OXA5CVF0FJMMC.jpg'}}},
#      {'id': '4f9b71a3e4b0d2a3a8a0c21c',
#       'createdAt': 1335587235,
#       'text': 'WiFi pass: c6cvb',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4f9b71a3e4b0d2a3a8a0c21c',
#       'lang': 'en',
#       'likes': {'count': 3,
#        'groups': [{'type': 'others',
#          'count': 3,
#          'items': [{'id': '71265074',
#            'firstName': 'xiao',
#            'lastName': 'meng',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_boy.png',
#             'default': True}},
#           {'id': '149405',
#            'firstName': 'Brunold',
#            'lastName': 'Loidl',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/149405_1AAQXWG4_66Lv2HV3zlmOWVI98nAWl4nIi1T3uPFawxt5ujtte3ZXUy-ZwZIlFKFZ1cZTWK5N.jpg'}},
#           {'id': '12314809',
#            'firstName': 'Neo',
#            'lastName': 'Clark',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/NFZHDR2T3B0SH5T4.jpg'}}]}],
#        'summary': '3 likes'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '22927853',
#        'firstName': 'Kir',
#        'lastName': '7og_ivs',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/W3AINUGGNZ4R0H2E.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/ccB5ad',
#  'timeZone': 'Asia/Shanghai',
#  'listed': {'count': 11,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 11,
#     'items': [{'id': '52ba5cb1498e2067109e9ba0',
#       'name': 'Starbucks in Shanghai, CN',
#       'description': 'When you a Drink a Coffee, Drink Starbucks',
#       'type': 'others',
#       'user': {'id': '6464696',
#        'firstName': 'Paul™',
#        'lastName': '[K|J]',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-YDG0YJMIKOMC4YHK.png'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/nareupon/list/starbucks-in-shanghai-cn',
#       'canonicalUrl': 'https://foursquare.com/nareupon/list/starbucks-in-shanghai-cn',
#       'createdAt': 1387945137,
#       'updatedAt': 1416119376,
#       'photo': {'id': '50cdbeb3e4b0cc5bc4aa7a81',
#        'createdAt': 1355660979,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/8554079_r4gf9W-xNKPkVEDQteI0de0lkIvn9ee0oyEFNC4gmR4.jpg',
#        'width': 480,
#        'height': 720,
#        'user': {'id': '8554079',
#         'firstName': 'Vivian',
#         'lastName': 'Fortunata',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/KWOQ3UFDA4FVGFSF.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 2},
#       'listItems': {'count': 29,
#        'items': [{'id': 'v4bf2301b189f0f47791eb862',
#          'createdAt': 1387945269,
#          'photo': {'id': '52a556f011d282bbfc895eed',
#           'createdAt': 1386567408,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/66989030_xoubXSGaWsJYHKjJmrOJkpMO-YARguyhXmKTE6J42hE.jpg',
#           'width': 960,
#           'height': 542,
#           'user': {'id': '66989030',
#            'firstName': 'Pa',
#            'lastName': 'Strel',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/66989030-FWOM4CQRPCDARYKU.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4e7c95a67d8b55fc471f3c76',
#       'name': 'Shanghai',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '11906002',
#        'firstName': 'Didem',
#        'lastName': 'Unsal',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/NKMMZ4THWKCY3PP0.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/11906002/list/shanghai',
#       'canonicalUrl': 'https://foursquare.com/user/11906002/list/shanghai',
#       'createdAt': 1316787622,
#       'updatedAt': 1351678166,
#       'followers': {'count': 3},
#       'listItems': {'count': 18,
#        'items': [{'id': 'v4bf2301b189f0f47791eb862',
#          'createdAt': 1316787622}]}},
#      {'id': '4f956b13e4b015eb3f092b2f',
#       'name': 'Starbucks in Shanghai',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '496300',
#        'firstName': 'Cary',
#        'lastName': 'Yang',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/RZDXA0Z5CQHYQLH3.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/caryyang/list/starbucks-in-shanghai',
#       'canonicalUrl': 'https://foursquare.com/caryyang/list/starbucks-in-shanghai',
#       'createdAt': 1335192339,
#       'updatedAt': 1403228776,
#       'photo': {'id': '4ee9b7a42c5bbde2179a71c4',
#        'createdAt': 1323939748,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/RIU5UPHZASUADASUAK3IMUD3VENCJWJXROK11PZ51PL5IBEA.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'id': '738411',
#         'firstName': 'Kevin',
#         'lastName': 'Chen',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/3RC5PT5VIX3PYXB3.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 21},
#       'listItems': {'count': 116,
#        'items': [{'id': 'v4bf2301b189f0f47791eb862',
#          'createdAt': 1335242522}]}},
#      {'id': '5432aee8498e2f8655fbb03c',
#       'name': '上海',
#       'description': '3年半、駐在で過ごした街、上海。',
#       'type': 'others',
#       'user': {'id': '4456560',
#        'firstName': 'Teddy',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/NNEBMT2AMEO3UU2L.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/okutetsuteddy/list/%E4%B8%8A%E6%B5%B7',
#       'canonicalUrl': 'https://foursquare.com/okutetsuteddy/list/%E4%B8%8A%E6%B5%B7',
#       'createdAt': 1412607720,
#       'updatedAt': 1413815955,
#       'photo': {'id': '52e51eda498eb9e24f7db01e',
#        'createdAt': 1390747354,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/66530775_QwV-BxzBSNL-vuaA8cmnIE5OyMGkFNZVyITGD7pEBCU.jpg',
#        'width': 720,
#        'height': 720,
#        'user': {'id': '66530775',
#         'firstName': 'Al',
#         'lastName': 'Rocco',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/66530775-R2TQBTTPDSZ2T3MN.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 3},
#       'listItems': {'count': 67,
#        'items': [{'id': 'v4bf2301b189f0f47791eb862',
#          'createdAt': 1413815955}]}}]}]},
#  'hours': {'status': 'Open until 9:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 9:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–9:00 PM'}],
#     'segments': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '9:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '10:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '9:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '9:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '10:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '10:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '10:00 AM–7:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4ba0c5b2f964a520ab7c37e3',
#   'name': 'Yuyuan Tourist Mart (豫园商城)',
#   'location': {'address': '269 Fangbang Zhong Road | 方浜中路269号',
#    'crossStreet': 'near Yu Garden',
#    'lat': 31.227912648814147,
#    'lng': 121.48718235873046,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 31.227912648814147,
#      'lng': 121.48718235873046}],
#    'postalCode': '200135',
#    'cc': 'CN',
#    'city': '上海市',
#    'state': '上海市',
#    'country': '中国',
#    'formattedAddress': ['269 Fangbang Zhong Road | 方浜中路269号 (near Yu Garden)',
#     '上海市',
#     '上海市, 200135',
#     '中国']},
#   'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#     'name': 'Market',
#     'pluralName': 'Markets',
#     'shortName': 'Market',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'Yuyuan Tourist Mart',
#    'lang': 'en',
#    'id': '4ba0c5b2f964a520ab7c37e3',
#    'canonicalUrl': 'https://foursquare.com/v/%E8%B1%AB%E5%9B%AD%E5%95%86%E5%9F%8E--yuyuan-tourist-mart/4ba0c5b2f964a520ab7c37e3'}],
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '¥',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '¥', 'priceTier': 1}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 6,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Full Bar',
#     'count': 5,
#     'items': [{'displayName': 'Full Bar', 'displayValue': 'Full Bar'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}]}]},
#  'bestPhoto': {'id': '5ce22c7aa5a315002cc26b80',
#   'createdAt': 1558326394,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/24952115_jNA3meQ1RGIAOK94iZLe_iB-3Mo-_0mpbF3i_uMJ4-s.jpg',
#   'width': 1920,
#   'height': 1440,
#   'visibility': 'public'}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.6

# %%
venue_id = '50b70a92e4b055ce10fff6bf' # ID of Costa Coffee (咖世家)
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/50b70a92e4b055ce10fff6bf?client_id=JRMAOQ23QH2AR2G01QNCFARI5IKTISMVT2PHM3D0DXKGHF5N&client_secret=M1P2CGJKPR0J1N1GMUV0P5CH1BGLFD3SHIPP4YTOFQ4NTATE&v=20190520'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '50b70a92e4b055ce10fff6bf',
#  'name': 'Costa Coffee (咖世家)',
#  'contact': {'twitter': 'costacoffee',
#   'facebook': '124310790964800',
#   'facebookUsername': 'CostaCoffee',
#   'facebookName': 'Costa Coffee'},
#  'location': {'address': '168 Zhoujin Rd | 昼锦路168号',
#   'crossStreet': 'Yu Fashion Garden | 豫城时尚',
#   'lat': 31.226842885699735,
#   'lng': 121.48780706417091,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 31.226842885699735,
#     'lng': 121.48780706417091}],
#   'postalCode': '200085',
#   'cc': 'CN',
#   'neighborhood': 'Yùyuán',
#   'city': 'Huangpu',
#   'state': '上海市',
#   'country': '中国',
#   'formattedAddress': ['168 Zhoujin Rd | 昼锦路168号 (Yu Fashion Garden | 豫城时尚), Yùyuán',
#    'Huangpu',
#    '上海市, 200085',
#    '中国']},
#  'canonicalUrl': 'https://foursquare.com/v/costa-coffee-%E5%92%96%E4%B8%96%E5%AE%B6/50b70a92e4b055ce10fff6bf',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'url': 'http://costa.net.cn',
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '¥'},
#  'likes': {'count': 3,
#   'groups': [{'type': 'others',
#     'count': 3,
#     'items': [{'id': '12130372',
#       'firstName': 'Snake',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/12130372_1mlozUR0_lNvAygV7ugxzNcGZvsSRHSlqk6p5cHI7EIOy9S2EFw_09fkgtxzRRKpwuYNdk_zu.jpg'}},
#      {'id': '7725946',
#       'firstName': 'Raymond',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/EDMGYK54D0BGQADT.jpg'}},
#      {'id': '18152977',
#       'firstName': 'Summer',
#       'lastName': 'Yeh',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/3PVA4LMPW2NCCX1V.jpg'}}]}],
#   'summary': '3 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.2,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 4,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'http://costa.net.cn/our_coffee_en.html',
#   'mobileUrl': 'http://costa.net.cn/our_coffee_en.html',
#   'externalUrl': 'http://costa.net.cn/our_coffee_en.html'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 17,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 17,
#     'items': [{'id': '515ba570e4b0bf0be701ab65',
#       'createdAt': 1364960624,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/6774399_ltps3KwWQyMc4KJ-lQl7DO2M06cfcMeiXzF1znxvBKk.jpg',
#       'width': 612,
#       'height': 612,
#       'user': {'id': '6774399',
#        'firstName': 'Ilnur',
#        'lastName': 'M',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/6774399-HLTAAQFJQ0LXN5QI.jpg'}},
#       'visibility': 'public'},
#      {'id': '52dceafd11d2b1e99d6ae020',
#       'createdAt': 1390209789,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/56928930_l4eeX5bmo3Vk3uta-czMTPuLsOxeRQeEJDB6lDNT978.jpg',
#       'width': 720,
#       'height': 960,
#       'user': {'id': '56928930',
#        'firstName': 'Peter',
#        'lastName': 'Lopez',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/52O0WIQYQ2K1AO5W.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1354173074,
#  'tips': {'count': 0,
#   'groups': [{'type': 'others', 'name': 'All tips', 'count': 0, 'items': []}]},
#  'shortUrl': 'http://4sq.com/Udk51q',
#  'timeZone': 'Asia/Shanghai',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4c318ff6ed37a593e9926a03',
#   'name': 'Yu Fashion Garden',
#   'location': {'address': '168 Zhoujin Rd | 昼锦路168号',
#    'crossStreet': 'near Henan S Rd | 近河南南路',
#    'lat': 31.227184484362564,
#    'lng': 121.4880524832372,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 31.227184484362564,
#      'lng': 121.4880524832372}],
#    'postalCode': '200085',
#    'cc': 'CN',
#    'neighborhood': 'Yùyuán',
#    'city': 'Huangpu',
#    'state': '上海市',
#    'country': '中国',
#    'formattedAddress': ['168 Zhoujin Rd | 昼锦路168号 (near Henan S Rd | 近河南南路), Yùyuán',
#     'Huangpu',
#     '上海市, 200085',
#     '中国']},
#   'categories': [{'id': '4bf58dd8d48988d1fd941735',
#     'name': 'Shopping Mall',
#     'pluralName': 'Shopping Malls',
#     'shortName': 'Mall',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'Yu Fashion Garden',
#    'lang': 'en',
#    'id': '4c318ff6ed37a593e9926a03',
#    'canonicalUrl': 'https://foursquare.com/v/yu-fashion-garden/4c318ff6ed37a593e9926a03'}],
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '¥',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '¥', 'priceTier': 1}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 6,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'No'}]}]},
#  'bestPhoto': {'id': '515ba570e4b0bf0be701ab65',
#   'createdAt': 1364960624,
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/6774399_ltps3KwWQyMc4KJ-lQl7DO2M06cfcMeiXzF1znxvBKk.jpg',
#   'width': 612,
#   'height': 612,
#   'visibility': 'public'}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.2

# %%
venue_id = '5b3da1542a7ab60039b2571f' # ID of Luckin Coffee (瑞幸咖啡)
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/5b3da1542a7ab60039b2571f?client_id=JRMAOQ23QH2AR2G01QNCFARI5IKTISMVT2PHM3D0DXKGHF5N&client_secret=M1P2CGJKPR0J1N1GMUV0P5CH1BGLFD3SHIPP4YTOFQ4NTATE&v=20190520'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '5b3da1542a7ab60039b2571f',
#  'name': 'Luckin Coffee (瑞幸咖啡)',
#  'contact': {},
#  'location': {'address': "No.10 Pu'an Road",
#   'lat': 31.226364,
#   'lng': 121.47625,
#   'labeledLatLngs': [{'label': 'display', 'lat': 31.226364, 'lng': 121.47625}],
#   'cc': 'CN',
#   'city': '上海市',
#   'state': '上海市',
#   'country': '中国',
#   'formattedAddress': ["No.10 Pu'an Road", '上海市', '上海市', '中国']},
#  'canonicalUrl': 'https://foursquare.com/v/luckin-coffee-%E7%91%9E%E5%B9%B8%E5%92%96%E5%95%A1/5b3da1542a7ab60039b2571f',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '¥'},
#  'likes': {'count': 0, 'groups': []},
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 5,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 5,
#     'items': [{'id': '5cda3fc30e3239002b14598a',
#       'createdAt': 1557807043,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/71668764_WQdwj3nNc1UyogPMbjH_C6Zcck56rGix-GOuPAn-GjU.jpg',
#       'width': 1440,
#       'height': 1920,
#       'user': {'id': '71668764',
#        'firstName': 'Yodi',
#        'lastName': 'Yang',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/71668764_IPqAOkhh_YuiDXw-fwAzTPQC_T1N71aojWYbwTeGsszh3_EHmlrlU0lesPJuNNE5JY-zs5hEF.jpg'}},
#       'visibility': 'public'},
#      {'id': '5b9a0cec5ba046002c5986ba',
#       'createdAt': 1536822508,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/71668764_BW2qo76bBTP2tU_CwQr0Wf6Nigrzvu9HtdInIX773M0.jpg',
#       'width': 1440,
#       'height': 1920,
#       'user': {'id': '71668764',
#        'firstName': 'Yodi',
#        'lastName': 'Yang',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/71668764_IPqAOkhh_YuiDXw-fwAzTPQC_T1N71aojWYbwTeGsszh3_EHmlrlU0lesPJuNNE5JY-zs5hEF.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1530765652,
#  'tips': {'count': 0,
#   'groups': [{'type': 'others', 'name': 'All tips', 'count': 0, 'items': []}]},
#  'shortUrl': 'https://4sq.com/2zdXlOe',
#  'timeZone': 'Asia/Shanghai',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4c957d44f7cfa1cd8f5bbe15',
#   'name': "Neon Kid's Place (霓虹儿童广场)",
#   'location': {'lat': 31.227704839771167,
#    'lng': 121.47205357124786,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 31.227704839771167,
#      'lng': 121.47205357124786}],
#    'cc': 'CN',
#    'city': 'Huangpu',
#    'state': '上海市',
#    'country': '中国',
#    'formattedAddress': ['Huangpu', '上海市', '中国']},
#   'categories': [{'id': '4bf58dd8d48988d105951735',
#     'name': 'Kids Store',
#     'pluralName': 'Kids Stores',
#     'shortName': 'Kids Store',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_kids_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': "Neon Kid's Place",
#    'lang': 'en',
#    'id': '4c957d44f7cfa1cd8f5bbe15',
#    'canonicalUrl': 'https://foursquare.com/v/neon-kids-place-%E9%9C%93%E8%99%B9%E5%84%BF%E7%AB%A5%E5%B9%BF%E5%9C%BA/4c957d44f7cfa1cd8f5bbe15'}],
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '¥',
#     'count': 1,
#     'items': [{'displayName': 'Price',
#       'displayValue': '¥',
#       'priceTier': 1}]}]},
#  'bestPhoto': {'id': '5cda3fc30e3239002b14598a',
#   'createdAt': 1557807043,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/71668764_WQdwj3nNc1UyogPMbjH_C6Zcck56rGix-GOuPAn-GjU.jpg',
#   'width': 1440,
#   'height': 1920,
#   'visibility': 'public'}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# ## Looks like in this area, the highest rating goes to a Costa, with a mark of 6.2; others either don't have a rating or just below what Costa has, for example, the second highest rated shop is a Starbucks with a mark of 5.6; and our newly emerged coffee force in China, Lucking coffee, has no ratings yet till this moment, this is perhaps the mainstream public opinion social medium platform is not Foursquare, but others such as "Da Zhong Dian ping (大众点评)".

# %% [markdown]
# ## Try to see tips that left by users, but found nothing, the reason is the same as above about no ratings with Lucking Coffee: that Foursquare is not a mainstream platform in China

# %%
result['response']['venue']['tips']['count']
# Out:
# 0

# %%
## Costa Tips
venue_id = '50c4614ce4b0b83e09a83a90' # ID of Costa
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce5fe22db04f52f5f1ed317'},
#  'response': {'tips': {'count': 0, 'items': []}}}

# %%
tips = results['response']['tips']['items']

# %%
tips
# Out:
# []
